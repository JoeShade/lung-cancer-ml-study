# %% [markdown]
# # Titanic EDA Blank Template
#
# Use this notebook as a fill-in template for the full exploratory data analysis workflow. Complete each code cell in order.

# %% [markdown]
# ## Step 1: Import libraries and set up
# Import the packages you need and configure plotting/display options.

# %%
# Import libraries
# Set plotting style or notebook display options

# %% [markdown]
# ## Step 2: Load the dataset
# Load the Titanic dataset and inspect the first few rows.

# %%
# Load the dataset
# Display the first rows

# %%
# Check dataset shape, column names, data types, and summary info

# %% [markdown]
# ## Step 3: Investigate and handle missing data
# Find missing values, decide how to handle them, and create a cleaned working copy.

# %%
# Count missing values in each column
# Visualize or summarize missingness if useful

# %%
# Handle missing values for columns such as Cabin, Embarked, and Age
# Document the strategy you choose

# %%
# Visualize Age by Pclass and Sex to support your imputation decision

# %% [markdown]
# ### Step 3 Notes
# Record the imputation or filling approach you choose for each column and why.

# %%
# Create a cleaned/imputed copy of the dataset

# %% [markdown]
# ## Step 4: Explore relationships between existing features and unusual data points

# %% [markdown]
# ### Step 4.1: Relationship between categorical features
# Example: `Sex` vs `Survived`.

# %%
# Create a count plot or another suitable chart for two categorical features

# %% [markdown]
# ### Step 4.2: Relationship between categorical and numeric features
# Example: `Pclass` vs `Fare`.

# %%
# Create a box plot or another suitable chart for a categorical and numeric feature
# Note any unusual values or potential outliers

# %% [markdown]
# ### Step 4.3: Relationship between two categorical features with survival split
# Example: `Pclass` vs `Sex`, separated by `Survived`.

# %%
# Build a categorical comparison plot with survival as an additional grouping

# %% [markdown]
# ### Step 4.4: Relationship between two numeric features
# Example: `Age` vs `Fare`.

# %%
# Create a scatter plot or another numeric-to-numeric comparison
# Consider coloring points by survival or another category

# %% [markdown]
# ### Step 4.5: Correlation matrix for numeric features
# Choose relevant numeric columns and inspect their correlations.

# %%
# Select numeric features
# Compute and visualize the correlation matrix

# %% [markdown]
# ### Step 4.6: Optional feature encoding for correlation checks
# Convert categorical variables such as `Sex` into numeric form if needed for additional analysis.

# %%
# Encode one or more categorical features for correlation analysis
# Recompute correlations if useful

# %% [markdown]
# ## Step 5: Add new features to the dataset

# %% [markdown]
# ### Step 5.1: Create new features
# Possible examples: `FamilySize`, `IsAlone`, `HasCabin`, `Deck`, `LogFare`.

# %%
# Create engineered features
# Keep changes in your cleaned/imputed DataFrame

# %% [markdown]
# ### Step 5.2: Visualize new features
# Check whether the engineered features appear useful for explaining survival.

# %%
# Visualize FamilySize vs Survived

# %%
# Visualize IsAlone vs Survived

# %%
# Visualize HasCabin vs Survived

# %%
# Visualize Deck vs Survived (optional if you created Deck)

# %%
# Visualize LogFare vs Survived (optional if you created LogFare)

# %%
# Recheck correlations including new features

# %% [markdown]
# ## Step 6: Summary
# Write a short summary of the main patterns, issues handled, engineered features, and useful findings.

# %%
# Optional: write summary notes here or convert this to a markdown cell

# %% [markdown]
# ## Step 7: Save the cleaned dataset

# %%
# Save the cleaned DataFrame to CSV
